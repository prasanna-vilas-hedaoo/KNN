# %%
import pandas as pd

# %%
data = pd.read_csv("/content/glass.csv")

# %%
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
list(data)
# Out:
# ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']

# %%
## split data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
x = data.iloc[0:, :-1]
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
y = data.iloc[:, -1]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
x.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %%
x.corr()
# Out:
#           RI        Na        Mg        Al        Si         K        Ca  \
# RI  1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K  -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca  0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe  0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
#
#           Ba        Fe
# RI -0.000386  0.143010
# Na  0.326603 -0.241346
# Mg -0.492262  0.083060
# Al  0.479404 -0.074402
# Si -0.102151 -0.094201
# K  -0.042618 -0.007719
# Ca -0.112841  0.124968
# Ba  1.000000 -0.058692
# ...

# %%
## data transformation

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()   ## range -3 to +3

# %%
s_tr = ss.fit_transform(x)

# %%
s_tr
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]])

# %%
s_df = pd.DataFrame(s_tr)

# %%
s_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#             7         8
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# ...

# %%
s_df.columns = list(x)

# %%
s_df.head()
# Out:
#          RI        Na        Mg        Al        Si         K        Ca  \
# 0  0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1 -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2 -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3 -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4 -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
#
#          Ba        Fe
# 0 -0.352877 -0.586451
# 1 -0.352877 -0.586451
# 2 -0.352877 -0.586451
# 3 -0.352877 -0.586451
# 4 -0.352877 -0.586451

# %%
## data partition

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(s_df,y, test_size = 0.30)

# %%
## fit the model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
## model predicted values
y_pred_train = knn.predict(x_train)
y_pred_test = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc1 = accuracy_score(y_train,y_pred_train)
acc2 = accuracy_score(y_test,y_pred_test)

# %%
print("training accuracy score:", acc1.round(2))
print("test accuracy score:", acc2.round(2))
# Out:
# training accuracy score: 0.7
# test accuracy score: 0.65

# %%
## trying other methods to increase accuracy

# %%
## cross validation

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %%
import numpy as np

# %%
knn = KNeighborsClassifier(n_neighbors=9)
training_accuracy = []
test_accuracy = []

for i in range(1,101):
    x_train,x_test,y_train,y_test = train_test_split(s_df,y, test_size=0.30,random_state=i)
    knn.fit(x_train,y_train)
    y_pred_train =  knn.predict(x_train)
    y_pred_test  =  knn.predict(x_test)
    training_accuracy.append(accuracy_score(y_train,y_pred_train))
    test_accuracy.append(accuracy_score(y_test,y_pred_test))


print("cross validation training result:",np.mean(training_accuracy).round(2))
print("cross validation test result:",np.mean(test_accuracy).round(2))
# Out:
# cross validation training result: 0.7
# cross validation test result: 0.63
